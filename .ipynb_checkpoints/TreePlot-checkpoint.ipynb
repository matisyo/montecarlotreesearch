# %%
from game.game import *
from montecarlo.uct import *

LARGO = 4
TABLERO_ALTO = 6
TABLERO_ANCHO = 7
t = Connect4(TABLERO_ANCHO, TABLERO_ALTO, LARGO)

# %%
m,a = uct(t, 3500, plot=True)
# Out:
# 0 (0.05,8,148), 1 (0.04,5,135), 2 (0.13,30,238), 3 (0.31,798,2575), 4 (-0.15,-9,59), 5 (0.13,30,238), 6 (-0.01,-1,107)

# %%
from memorymontecarlo.memcts import Memcts
game_board = Connect4(7, 6, 4)
agentemmc1 = Memcts(game_board)
move = agentemmc1.uct(300, plot=True,silent=False)[1]
# Out:
# 0 (-0.09,-2,22), 1 (-0.14,-3,21), 2 (0.22,14,65), 3 (0.31,36,115), 4 (0.0,0,26), 5 (0.0,0,30), 6 (-0.14,-3,21)
